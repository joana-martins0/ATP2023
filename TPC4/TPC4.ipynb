# %%
def menu ():
    print("1. Criar lista de número aleatórios entre 1 e 100.")
    print("2. Criar lista de números introduzidos pelo utilizador. ")
    print("3. Soma dos elemntos de uma lista.")
    print("4. Média dos elementos de uma lista.")
    print("5. Maior elemento de uma lista.")
    print("6. Menor elemento de uma lista.")
    print("7. Conferir se a lista está ordenada por ordem crescente.")
    print("8. Conferir se a lista está ordenada por ordem decrescente.")
    print("9. Procura um elemento da lista.")
    print ("0. Sair.")
menu()

#função para a primeira opção
import random 
def criaLista(n):
    lista=[]
    for i in range (n):
        num = random.randint(1,100)
        lista.append(num)
    return lista

#função para a segunda opção

def leLista(N):
    lista = []
    i = 0
    while i <= N:
        num = int(input("Introduza um número: "))
        lista.append(num)
        i = i + 1
    return lista

#função para a terceira opção

def somaLista(lista):
    soma = 0
    for numero in lista:
        soma = numero + soma 
    return soma

#função para a quarta opção

def mediaLista(lista):
    media = 0
    soma = 0
    for numero in lista:
        soma = numero + soma 
        media = soma / len(lista)
    return media

#função para a quinta opção

def maiorLista(lista):
    maior = lista[0] #inicia com o primeiro elemento da lista
    for numero in lista:
        if numero > maior:
            maior = numero
    return maior

#função para a sexta opção

def menorLista(lista):
    menor = lista[0] #inicia com o primeiro elemento da lista
    for numero in lista:
        if numero < menor:
            menor = numero
    return menor

#função para a sétima opção

def estaOrdenadaC(lista):
    l = 0
    valor = True
    while l < len(lista)-1:
        if lista [l] > lista[l+1]:
            valor = False
        l = l + 1 
    return valor

#função para a oitava opção

def estaOrdenadaD (lista):
    l = 0
    valor = True
    while l < len (lista)-1:
        if lista[l] < lista [l+1]:
            valor = False
        l = l + 1
    return valor 

#função para a nona opção
"""
def procurarElemento(lista, elem):
    valor = -1
    if elem in lista:
        valor = lista.index(elem)
    return valor 
"""
def procurarElemento (lista, elem):
    valor = -1 
    posicao = 0
    for item in lista:
        if item == elem:
            valor = posicao
        posicao = posicao +1 
    return valor


op = "1"
while op != "0":
    menu()
    op = input("Escolhe a tua opção: ")
    if op == "0":
        print ("Até à próxima!")
    elif op == "1":
        n = int(input("Quantos número é que quer introduzir: "))
        lis = criaLista(n)
        print ("Lista criada:", lis)
    elif op == "2":
        N = int(input("Quantos número é que quer introduzir: "))
        lis = leLista(N)
        print("Lista criada:", lis)
    elif op == "3":
        resultado = somaLista(lis)
        print("Soma dos elementos:", resultado)
    elif op == "4":
        resultado = mediaLista(lis)
        print("Media dos elementos:", resultado)
    elif op == "5":
        resultado = maiorLista(lis)
        print("Maior elemento:", resultado)
    elif op == "6":
        resultado = menorLista(lis)
        print("Menor elemento:", resultado)
    elif op == "7":
        resultado = estaOrdenadaC(lis)
        print(resultado)
    elif op == "8":
       resultado = estaOrdenadaD(lis)
       print(resultado)
    elif op == "9":
        elem = int(input("Introduza o número que quer procurar na lista: "))
        resultado = procurarElemento(lis,elem)
        print(resultado)
    else:
        print("Opção Inválida!")
