# %% [markdown]
# ### TPC7: Construir uma aplicação para manipular polinómios\n
# Depois da aula da semana passada, já tens algumas funções desenvolvidas que te irão ajudar a construir a aplicação que se descreve a seguir.
#     "\n",
#  Aquecimento: Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula
#        - `x^7 - 3.7x^4 + 5x^3 - 88
#       - `2x^2 + 17
#        - `7x^4 + 6x^3 - x^2 + 43
#        - `x^4
#         - `x^2
#       - `x^3
#   "* Desenvolve as seguintes funcionalidades que não foram trabalhadas na aula:,
#     "    1. Define uma função que dado um polinómio calcula a sua derivada,
#     "    2. Define uma função que recebe dois polinómios `p1` e `p2` e calcula um novo polinómio correspondente à soma de `p1` e `p2`,
#     "    3. Define uma função que recebe um polinómio e o desenha num gráfico.,
#
#     "* Num ficheiro Python, cria uma aplicação para manipular polinómios com as seguintes operações,
#     "    1. Criar um polinómio interativamente,
#     "    2. Ler uma lista de polinómios de um ficheiro,
#     "    3. Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um,
#     "    4. Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio),
#     "    5. Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau,
#     "    6. Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem,
#     "    7. Derivada: mostra uma tabela com os polinómios e as respetivas derivadas,
#     "    8. Somar dois polinómios: indicando os seus números de ordem,
#     "    9. Gerar um gráfico para o polinómio,
#     "    10. Gravar num ficheiro os polinómios em memória,
#     "    0. Sair da aplicação.

# %%
def criaPolIn():
    resPol = []
    grau = int(input("Insira o grau do polinómio: "))
    while grau >= 0:
        coeficiente = int(input("Introduza um número: "))
        if coeficiente !=0: 
            monomio = (coeficiente,grau) 
            resPol.append(monomio)
        grau = grau - 1 #para ir do grau maior para o grau menor
    return resPol 

criaPolIn()

def lerPol(fnome):
    coefs = []
    fPol = open(fnome)
    for linha in fPol:
        coef = float(linha.strip())
        coefs.append(coef)
    return coefs

def guardarPolinomios(listap):
    numeroOrdem = 1
    for polinomio in len(listap):
        print("Polinómio", numeroOrdem, polinomio)
        numeroOrdem += 1
    return 

def calcularValorPolinomio(listap, numOrdem, ponto):
    if numOrdem < 1 and numOrdem > len(listap):
        print("Inválido!")
    polinomio = listap[numOrdem - 1]
    valor = 0
    for coeficiente, expoente in polinomio:
        valor = valor + coeficiente*(ponto**expoente)
    return valor

def listarPolinomiosGrau(listap):
    grau = 0
    numOrdem = 1
    for polinomio in listap:
        for coeficiente, expoente in polinomio:
            if expoente > grau:
                grau = expoente
        numOrdem = numOrdem + 1
        print("Polinómio", numOrdem, ":", polinomio, ", Grau:", grau)
    return listap

def grauPolinomios(listap):
    maior = 0
    numOrdem =0
    for p in listap:
        grau = 0
        for coeficiente, expoente in p:
            if expoente > grau:
                grau = expoente
        if grau > maior:
            maior = grau
        else:
            maior
            numOrdem += 1
    return maior, numOrdem

def derivarPolinomio(p):
    novoP = []
    for coeficiente, grau in p:
        if grau > 1:
            p1=(coeficiente*grau, grau-1)
            novoP.append(p1)
        elif grau == 1:
            p2=(coeficiente*grau,0)
            novoP.append(p2)

    return novoP

def somarPolinomios(p1,p2):
    soma = []
    i = 0
    j = 0
    while i < len(p1) and j < len(p2):
        coef1, exp1 = p1[i]
        coef2, exp2 = p2[j]
        if exp1 == exp2:
            termo_soma = (coef1 + coef2, exp1)
            soma.append(termo_soma)
            i = i + 1
            j = j + 1
        elif exp1 < exp2:
            soma.append((coef1, exp1))
            i = i + 1
        else:
            soma.append((coef2, exp2))
            j = j + 1
    # Adicionar os termos restantes, se houver
    while i < len(p1):
        soma.append(p1[i])
        i = i + 1
    while j < len(p2):
        soma.append(p2[j])
        j = j + 1
    return soma

import numpy as np
import matplotlib.pyplot as plt
def graficoPol(polinomio):
    coef = []
    exp = []
    for coeficiente, expoente in polinomio:
        coef.append(coeficiente)
        exp.append(expoente)
    x = np.linspace(-10, 10, 400)
    y = np.polyval(coef, x)
    plt.plot(x, y)
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.title('Gráfico do Polinómio')

# Mostra o gráfico na tela
    plt.grid(True)
    plt.show()

def guardarPolinomios(listap, fnome):
    fPol = open(fnome, "w")
    for pol in listap:
        for monomio in pol:
            coeficiente, expoente = monomio
            fPol.write(str(coeficiente) + "," + "str(expoente)" + "|")
        fPol.write("\n")
    fPol.close()
    return

def menu():
    print("""Bem-vindo! 
Menu:
    (1) Criar um polinómio interativamente.
    (2) Ler uma lista de polinómios de um ficheiro.
    (3) Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um.
    (4) Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio).
    (5) Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau.
    (6) Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem.
    (7) Derivada: mostra uma tabela com os polinómios e as respetivas derivadas.
    (8) Somar dois polinómios: indicando os seus números de ordem.
    (9) Gerar um gráfico para o polinómio.
    (10) Gravar num ficheiro os polinómios em memória.
    (0) Sair """)
    return

menu()
function=int(input("O que pretende fazer?"))
print("")
lista = []
while function !=0:
    if function == 1:
        polinomio = criaPolIn()
        lista.append(polinomio)

    elif function == 2:
        nomeArquivo = input("Insira o nome do arquivo: ")

    elif function == 3:
       guardarPolinomios(lista)
    
    elif function == 4:
        numOrdem = int(input("Insira o número de ordem do polinómio: "))
        ponto = float(input("Insira o ponto para avaliação: "))
        valor =  calcularValorPolinomio(lista, numOrdem, ponto)
    
    elif function == 5:
        listarPolinomiosGrau(lista)
    
    elif function == 6:
        maior, numOrdem = grauPolinomios(lista)

    elif function == 7:
        for polinomio in lista:
            derivada = derivarPolinomio(polinomio)
       
    elif function == 8:
        numOrdem1 = int(input("Insira o número de ordem do primeiro polinómio: "))
        numOrdem2 = int(input("Insira o número de ordem do segundo polinómio: "))
        somarPolinomios (lista,numOrdem1, numOrdem2)

    elif function == 9:
        numOrdem = int(input("Insira o número de ordem do polinómio para gerar o gráfico: "))
        graficoPol(lista[numOrdem - 1])
        
    elif function == 10:
        nomeArquivo = input("Insira o nome do arquivo: ")
        guardarPolinomios(lista, nomeArquivo)
    
    elif function == "0":
        print ("Sair")
        
    function = int(input("O que pretende consultar de seguida?"))
print("")
print("Saiu do programa! Volte sempre.")
print("")
